# %%
people = {
    "first": ["Corey", 'Jane', 'John', "Tony", 'Spyder', 'Capten'], 
    "last": ["Schafer", 'Doe', 'Doe', "Stark", 'Man', 'America'], 
    "email": ["CoreyMSchafer@gmail.com", 'JaneDoe@email.com', 'JohnDoe@email.com', "TonyStark@gmail.com", 'Spyder@email.com', 'Capamwerica@email.com']
}

# %%
import pandas as pd
df = pd.DataFrame(people)
df.head(10)
# Out:
#     first     last                    email
# 0   Corey  Schafer  CoreyMSchafer@gmail.com
# 1    Jane      Doe        JaneDoe@email.com
# 2    John      Doe        JohnDoe@email.com
# 3    Tony    Stark      TonyStark@gmail.com
# 4  Spyder      Man         Spyder@email.com
# 5  Capten  America    Capamwerica@email.com

# %%
df.sort_values(by='email')
# Out:
#     first     last                    email
# 5  Capten  America    Capamwerica@email.com
# 0   Corey  Schafer  CoreyMSchafer@gmail.com
# 1    Jane      Doe        JaneDoe@email.com
# 2    John      Doe        JohnDoe@email.com
# 4  Spyder      Man         Spyder@email.com
# 3    Tony    Stark      TonyStark@gmail.com

# %%
df.sort_values(by='email', ascending=False)
# Out:
#     first     last                    email
# 3    Tony    Stark      TonyStark@gmail.com
# 4  Spyder      Man         Spyder@email.com
# 2    John      Doe        JohnDoe@email.com
# 1    Jane      Doe        JaneDoe@email.com
# 0   Corey  Schafer  CoreyMSchafer@gmail.com
# 5  Capten  America    Capamwerica@email.com

# %%
df.sort_index()
# Out:
#     first     last                    email
# 0   Corey  Schafer  CoreyMSchafer@gmail.com
# 1    Jane      Doe        JaneDoe@email.com
# 2    John      Doe        JohnDoe@email.com
# 3    Tony    Stark      TonyStark@gmail.com
# 4  Spyder      Man         Spyder@email.com
# 5  Capten  America    Capamwerica@email.com

# %%
df['full_name'] = df['first'] + ' ' + df['last']

# %%
df
# Out:
#     first     last                    email       full_name
# 0   Corey  Schafer  CoreyMSchafer@gmail.com   Corey Schafer
# 1    Jane      Doe        JaneDoe@email.com        Jane Doe
# 2    John      Doe        JohnDoe@email.com        John Doe
# 3    Tony    Stark      TonyStark@gmail.com      Tony Stark
# 4  Spyder      Man         Spyder@email.com      Spyder Man
# 5  Capten  America    Capamwerica@email.com  Capten America

# %%
df.drop('first', axis=1, inplace=True)
df
# Out:
#       last                    email       full_name
# 0  Schafer  CoreyMSchafer@gmail.com   Corey Schafer
# 1      Doe        JaneDoe@email.com        Jane Doe
# 2      Doe        JohnDoe@email.com        John Doe
# 3    Stark      TonyStark@gmail.com      Tony Stark
# 4      Man         Spyder@email.com      Spyder Man
# 5  America    Capamwerica@email.com  Capten America

# %%
df
# Out:
#                      email       full_name
# 0  CoreyMSchafer@gmail.com   Corey Schafer
# 1        JaneDoe@email.com        Jane Doe
# 2        JohnDoe@email.com        John Doe
# 3      TonyStark@gmail.com      Tony Stark
# 4         Spyder@email.com      Spyder Man
# 5    Capamwerica@email.com  Capten America

# %%
df[['first', 'last']] = df['full_name'].str.split(' ', expand=True)
df
# Out:
#                      email       full_name   first     last
# 0  CoreyMSchafer@gmail.com   Corey Schafer   Corey  Schafer
# 1        JaneDoe@email.com        Jane Doe    Jane      Doe
# 2        JohnDoe@email.com        John Doe    John      Doe
# 3      TonyStark@gmail.com      Tony Stark    Tony    Stark
# 4         Spyder@email.com      Spyder Man  Spyder      Man
# 5    Capamwerica@email.com  Capten America  Capten  America

# %%
df.drop('full_name', axis=1, inplace=True)

# %%
df
# Out:
#                      email   first     last
# 0  CoreyMSchafer@gmail.com   Corey  Schafer
# 1        JaneDoe@email.com    Jane      Doe
# 2        JohnDoe@email.com    John      Doe
# 3      TonyStark@gmail.com    Tony    Stark
# 4         Spyder@email.com  Spyder      Man
# 5    Capamwerica@email.com  Capten  America

# %%
df.append({'email': 'DanielRicciardo@gmail.com'}, ignore_index=True)
# Out:
#                        email   first     last
# 0    CoreyMSchafer@gmail.com   Corey  Schafer
# 1          JaneDoe@email.com    Jane      Doe
# 2          JohnDoe@email.com    John      Doe
# 3        TonyStark@gmail.com    Tony    Stark
# 4           Spyder@email.com  Spyder      Man
# 5      Capamwerica@email.com  Capten  America
# 6  DanielRicciardo@gmail.com     NaN      NaN

# %%
 people = {
    "first_name": ["Tony", 'Spyder', 'Capten'], 
    "last_name": ["Stark", 'Man', 'America'], 
    "email": ["TonyStark@gmail.com", 'Spyder@email.com', 'Capamwerica@email.com']
}

# %%
df2 = pd.DataFrame(people)

# %%
df2
# Out:
#   first_name last_name                  email
# 0       Tony     Stark    TonyStark@gmail.com
# 1     Spyder       Man       Spyder@email.com
# 2     Capten   America  Capamwerica@email.com

# %%
df
# Out:
#                      email   first     last
# 0  CoreyMSchafer@gmail.com   Corey  Schafer
# 1        JaneDoe@email.com    Jane      Doe
# 2        JohnDoe@email.com    John      Doe
# 3      TonyStark@gmail.com    Tony    Stark
# 4         Spyder@email.com  Spyder      Man
# 5    Capamwerica@email.com  Capten  America

# %%
df2.colums = ['first', 'last', 'email']
# Out:
# <ipython-input-31-e071a537766c>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df2.colums = ['first', 'last', 'email']

# %%
df2.rename(columns={'first_name': 'first', 'last_name': 'last'}, inplace=True)

# %%
df2
# Out:
#     first     last                  email
# 0    Tony    Stark    TonyStark@gmail.com
# 1  Spyder      Man       Spyder@email.com
# 2  Capten  America  Capamwerica@email.com

# %%
df3 = df.append(df2)
df3
# Out:
#                      email   first     last
# 0  CoreyMSchafer@gmail.com   Corey  Schafer
# 1        JaneDoe@email.com    Jane      Doe
# 2        JohnDoe@email.com    John      Doe
# 3      TonyStark@gmail.com    Tony    Stark
# 4         Spyder@email.com  Spyder      Man
# 5    Capamwerica@email.com  Capten  America
# 0      TonyStark@gmail.com    Tony    Stark
# 1         Spyder@email.com  Spyder      Man
# 2    Capamwerica@email.com  Capten  America

# %%
filt = df3['last'] == 'Stark'
x = df3[filt].index
df3.drop(x, inplace=True)
df3
# Out:
#                    email   first     last
# 1      JaneDoe@email.com    Jane      Doe
# 2      JohnDoe@email.com    John      Doe
# 4       Spyder@email.com  Spyder      Man
# 5  Capamwerica@email.com  Capten  America
# 1       Spyder@email.com  Spyder      Man
# 2  Capamwerica@email.com  Capten  America

# %%
# d_parser = lambda x: pd.datetime.strptime(x, '%Y-%m-%d %I-%p')
import pandas as pd
dfD = pd.read_csv('ETH_1h.csv')

# %%
dfD
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
dfD.describe()
# Out:
#                Open          High           Low         Close        Volume
# count  23674.000000  23674.000000  23674.000000  23674.000000  2.367400e+04
# mean     324.933372    327.317109    322.255521    324.926601  2.011035e+06
# std      236.189068    238.539115    233.365042    236.192308  3.673646e+06
# min       81.290000     82.000000     80.600000     81.290000  0.000000e+00
# 25%      171.522500    172.472500    170.500000    171.512500  3.993914e+05
# 50%      229.745000    231.725000    228.100000    229.725000  9.146454e+05
# 75%      402.797500    405.427500    400.030000    402.797500  2.098111e+06
# max     1418.610000   1419.960000   1388.990000   1418.610000  8.569790e+07

# %%
type(dfD['Date'])
# Out:
# pandas.core.series.Series

# %%
pd.to_datetime(dfD['Date'], format = '%Y-%m-%d %I-%p')
# Out:
# 0       2020-03-13 20:00:00
# 1       2020-03-13 19:00:00
# 2       2020-03-13 18:00:00
# 3       2020-03-13 17:00:00
# 4       2020-03-13 16:00:00
#                 ...
# 23669   2017-07-01 15:00:00
# 23670   2017-07-01 14:00:00
# 23671   2017-07-01 13:00:00
# 23672   2017-07-01 12:00:00
# 23673   2017-07-01 11:00:00
# Name: Date, Length: 23674, dtype: datetime64[ns]

# %%
dfD['Date'] = pd.to_datetime(dfD['Date'], format = '%Y-%m-%d %I-%p')

# %%
dfD
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
dfD.loc[0,'Date'].day_name()
# Out:
# 'Friday'

# %%
dfD['DayOfWeek'] = dfD['Date'].dt.day_name()

# %%
dfD
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#       dayOfWeek DayOfWeek
# ...

# %%
type(dfD['Date'])
# Out:
# pandas.core.series.Series

# %%
dfD['Date'].min()
# Out:
# Timestamp('2017-07-01 11:00:00')

# %%
dfD['Date'].max()
# Out:
# Timestamp('2020-03-13 20:00:00')

# %%
time_delta = dfD['Date'].max() - dfD['Date'].min()
time_delta
# Out:
# Timedelta('986 days 09:00:00')

# %%
filt = (dfD['Date'] >= '2019-01') & (dfD['Date'] <=  '2019-05')

# %%
dfD.loc[filt]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 7628  2019-05-01 00:00:00  ETHUSD  160.40  163.25  160.29  161.59  1669912.13
# 7629  2019-04-30 23:00:00  ETHUSD  160.45  160.62  159.61  160.40   712852.31
# 7630  2019-04-30 22:00:00  ETHUSD  157.61  161.20  157.56  160.45  2515387.20
# 7631  2019-04-30 21:00:00  ETHUSD  156.43  158.06  156.19  157.61   746770.09
# 7632  2019-04-30 20:00:00  ETHUSD  156.13  156.91  155.76  156.43   468094.79
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#        dayOfWeek  DayOfWeek
# ...

# %%
dfD.set_index('Date', inplace=True)

# %%
dfD['2019-04-04']
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2019-04-04 23:00:00  ETHUSD  157.22  158.50  157.02  157.65   562503.23
# 2019-04-04 22:00:00  ETHUSD  158.75  159.36  157.08  157.22   498213.28
# 2019-04-04 21:00:00  ETHUSD  156.08  159.36  155.52  158.75  1207832.23
# 2019-04-04 20:00:00  ETHUSD  154.62  156.09  154.15  156.08   985609.21
# 2019-04-04 19:00:00  ETHUSD  155.66  156.33  154.50  154.62   814261.94
# 2019-04-04 18:00:00  ETHUSD  154.01  156.80  153.50  155.66  1642325.79
# 2019-04-04 17:00:00  ETHUSD  155.70  157.88  154.00  154.01  3031467.32
# 2019-04-04 16:00:00  ETHUSD  161.28  161.34  155.54  155.70  2422406.00
# 2019-04-04 15:00:00  ETHUSD  161.18  161.36  159.61  161.28   795055.15
# 2019-04-04 14:00:00  ETHUSD  161.69  162.55  161.01  161.18   874064.93
# 2019-04-04 13:00:00  ETHUSD  162.14  162.48  161.05  161.69   567316.38
# 2019-04-04 12:00:00  ETHUSD  161.80  162.57  160.81  162.14   602582.95
# ...

# %%
dfD['2020-01':'2020-02']['Open']
# Out:
# Date
# 2020-02-29 23:00:00    223.35
# 2020-02-29 22:00:00    223.48
# 2020-02-29 21:00:00    224.63
# 2020-02-29 20:00:00    225.31
# 2020-02-29 19:00:00    225.09
#                         ...
# 2020-01-01 04:00:00    129.57
# 2020-01-01 03:00:00    130.37
# 2020-01-01 02:00:00    130.14
# 2020-01-01 01:00:00    128.34
# 2020-01-01 00:00:00    128.54
# Name: Open, Length: 1440, dtype: float64

# %%
import numpy as np
people = {
    'first': ['Corey', 'Jane', 'John', 'Chris', np.nan, None, 'NA'], 
    'last': ['Schafer', 'Doe', 'Doe', 'Schafer', np.nan, np.nan, 'Missing'], 
    'email': ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com', None, np.nan, 'Anonymous@email.com', 'NA'],
    'age': ['33', '55', '63', '36', None, None, 'Missing']
}

# %%
dfc = pd.DataFrame(people)
dfc
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN     None
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
dfc.isna().sum()
# Out:
# first    2
# last     2
# email    2
# age      2
# dtype: int64

# %%
dfc.dropna()
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 6     NA  Missing                       NA  Missing

# %%
dfc.dropna(axis='index', how='any')
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 6     NA  Missing                       NA  Missing

# %%
dfc.dropna(axis='index', how='all')
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
dfc.dropna(axis='index', how='all', subset=['email', 'first'])
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
dfc.fillna(0)
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                        0       36
# 4      0        0                        0        0
# 5      0        0      Anonymous@email.com        0
# 6     NA  Missing                       NA  Missing

# %%
dfc.replace('NA', np.nan, inplace=True)
dfc.replace('Missing', np.nan, inplace=True)

# %%
dfc.fillna(0)
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@email.com  55
# 2   John      Doe        JohnDoe@email.com  63
# 3  Chris  Schafer                        0  36
# 4      0        0                        0   0
# 5      0        0      Anonymous@email.com   0
# 6      0        0                        0   0

# %%
dfc['age'] = dfc['age'].astype(float)

# %%
dfc['age'].mean()
# Out:
# 46.75

# %%
dfc['age'].median()
# Out:
# 45.5

# %%
na_vals = ['NA', 'Missing']
dfc1 = pd.read_csv('survey_results_public.csv', index_col='Respondent', na_values=na_vals)
schema_df = pd.read_csv('survey_results_schema.csv', index_col='Column')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
dfc1.head(5)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
dfc1['YearsCode']
# Out:
# Respondent
# 1          4
# 2        NaN
# 3          3
# 4          3
# 5         16
#         ...
# 88377    NaN
# 88601    NaN
# 88802    NaN
# 88816    NaN
# 88863      8
# Name: YearsCode, Length: 88883, dtype: object

# %%
dfc1['YearsCode'].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 'Less than 1 year', '30', '9', '26', '40', '19',
#        '15', '20', '28', '25', '1', '22', '11', '33', '50', '41', '18',
#        '34', '24', '23', '42', '27', '21', '36', '32', '39', '38', '31',
#        '37', 'More than 50 years', '29', '44', '45', '48', '46', '43',
#        '47', '49'], dtype=object)

# %%
dfc1.replace('Less than 1 year', 0, inplace=True)

# %%
dfc1.replace('More than 50 years',51, inplace=True)

# %%
dfc1['YearsCode'] = dfc1['YearsCode'].astype(float)

# %%
dfc1['YearsCode'].mean()
# Out:
# 11.589040005458392

# %%
df
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
dfg = pd.read_csv('survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('survey_results_schema.csv', index_col='Column')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
dfg.head(10)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# 6           I am not primarily a developer, but I write co...      Yes
# 7                              I am a developer by profession       No
# 8                                 I code primarily as a hobby      Yes
# 9                              I am a developer by profession      Yes
# 10                             I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# ...

# %%
dfg['SocialMedia'].value_counts()
# Out:
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: SocialMedia, dtype: int64

# %%
dfg['SocialMedia'].value_counts(normalize=True)
# Out:
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: SocialMedia, dtype: float64

# %%
country_group = dfg.groupby(['Country'])

# %%
country_group.get_group('United Kingdom').head(5)
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 16                  I am a developer by profession      Yes
# 76                  I am a developer by profession       No
# 80                  I am a developer by profession      Yes
# 82                  I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 1                                                       Never
# 16                                                      Never
# 76                                                      Never
# 80          Less than once a month but more than once per ...
# 82                                 Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 16          The quality of OSS and closed source software ...
# ...

# %%
filt = (dfg['Country'] == 'United Kingdom')

# %%
dfg.loc[filt, 'SocialMedia'].value_counts()
# Out:
# Reddit                      1199
# Twitter                      995
# WhatsApp                     909
# Facebook                     811
# YouTube                      681
# I don't use social media     372
# Instagram                    318
# LinkedIn                     175
# Snapchat                      70
# WeChat 微信                     11
# VK ВКонта́кте                  3
# Youku Tudou 优酷                 1
# Weibo 新浪微博                     1
# Name: SocialMedia, dtype: int64

# %%
dfg.loc[filt]['SocialMedia'].value_counts()
# Out:
# Reddit                      1199
# Twitter                      995
# WhatsApp                     909
# Facebook                     811
# YouTube                      681
# I don't use social media     372
# Instagram                    318
# LinkedIn                     175
# Snapchat                      70
# WeChat 微信                     11
# VK ВКонта́кте                  3
# Youku Tudou 优酷                 1
# Weibo 新浪微博                     1
# Name: SocialMedia, dtype: int64

# %%
dfg.loc[filt]['SocialMedia'].value_counts(normalize=True)
# Out:
# Reddit                      0.216192
# Twitter                     0.179409
# WhatsApp                    0.163902
# Facebook                    0.146232
# YouTube                     0.122791
# I don't use social media    0.067075
# Instagram                   0.057339
# LinkedIn                    0.031554
# Snapchat                    0.012622
# WeChat 微信                   0.001983
# VK ВКонта́кте               0.000541
# Youku Tudou 优酷              0.000180
# Weibo 新浪微博                  0.000180
# Name: SocialMedia, dtype: float64

# %%
country_group['SocialMedia'].value_counts()
# Out:
# Country      SocialMedia
# Afghanistan  Facebook                    15
#              YouTube                      9
#              I don't use social media     6
#              WhatsApp                     4
#              Instagram                    1
#                                          ..
# Zimbabwe     Facebook                     3
#              YouTube                      3
#              Instagram                    2
#              LinkedIn                     2
#              Reddit                       1
# Name: SocialMedia, Length: 1220, dtype: int64

# %%
country_group['SocialMedia'].value_counts().loc['India']
# Out:
# SocialMedia
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# Hello                          5
# WeChat 微信                      5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: SocialMedia, dtype: int64

# %%
country_group['ConvertedComp'].mean()
# Out:
# 28057.664916229056

# %%
country_group['ConvertedComp'].median().loc['India']
# Out:
# 10080.0

# %%
country_group['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
country_group['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum()).loc['United Kingdom']
# Out:
# 2384
