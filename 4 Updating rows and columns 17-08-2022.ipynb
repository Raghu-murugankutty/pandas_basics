# %%
people = {
    "first": ["Corey", 'Jane', 'John'], 
    "last": ["Schafer", 'Doe', 'Doe'], 
    "email": ["CoreyMSchafer@gmail.com", 'JaneDoe@email.com', 'JohnDoe@email.com']
}

# %%
import pandas as pd

df = pd.DataFrame(people)
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %% [markdown]
# ### updating column names

# %%
df.columns = ['first_name', 'last_name', 'email']

# %%
df
# Out:
#   first_name last_name                    email
# 0      Corey   Schafer  CoreyMSchafer@gmail.com
# 1       Jane       Doe        JaneDoe@email.com
# 2       John       Doe        JohnDoe@email.com

# %% [markdown]
# # ==========================================

# %%
df.columns = [x.upper() for x in df.columns]

# %%
df
# Out:
#   FIRST_NAME LAST_NAME                    EMAIL
# 0      Corey   Schafer  CoreyMSchafer@gmail.com
# 1       Jane       Doe        JaneDoe@email.com
# 2       John       Doe        JohnDoe@email.com

# %%
df.colums = [x.lower() for x in df.columns]

# %%
df
# Out:
#   FIRST_NAME LAST_NAME                    EMAIL
# 0      Corey   Schafer  CoreyMSchafer@gmail.com
# 1       Jane       Doe        JaneDoe@email.com
# 2       John       Doe        JohnDoe@email.com

# %%
df.columns = df.columns.str.replace('_', ' ')
df
# Out:
#   FIRST NAME LAST NAME                    EMAIL
# 0      Corey   Schafer  CoreyMSchafer@gmail.com
# 1       Jane       Doe        JaneDoe@email.com
# 2       John       Doe        JohnDoe@email.com

# %%
df.columns = df.columns.str.replace(' ', '_')
df
# Out:
#   FIRST_NAME LAST_NAME                    EMAIL
# 0      Corey   Schafer  CoreyMSchafer@gmail.com
# 1       Jane       Doe        JaneDoe@email.com
# 2       John       Doe        JohnDoe@email.com

# %%
df.rename(columns = {'FIRST_NAME': 'firse', 'LAST_NAME': 'last', 'EMAIL': 'email'}, inplace=True)

# %%
df
# Out:
#    firse     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %% [markdown]
# # ==================================================

# %% [markdown]
# # Updating rows

# %%
df.loc[2] = ['Corey','Schafer', 'CoreySchafer@gmail.com']

# %%
df
# Out:
#    firse     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2  Corey  Schafer   CoreySchafer@gmail.com

# %% [markdown]
# ### updating specific columns
#
# Scenario1: can update entire row
# scenario2: can update specific column values, for that we can filter the data using loc n,column values = new values

# %%
df.loc[2, ['firse', 'last']]
# Out:
# firse      Corey
# last     Schafer
# Name: 2, dtype: object

# %%
df.rename (columns ={'firse': 'first_name', 'last': 'last_name'}, inplace= True)

# %%
df
# Out:
#   first_name last_name                    email
# 0      Corey   Schafer  CoreyMSchafer@gmail.com
# 1       Jane       Doe        JaneDoe@email.com
# 2      Corey   Schafer   CoreySchafer@gmail.com

# %%
df.loc[2, ['first_name', 'last_name']] = ['daniel', 'ricciardo']

# %%
df
# Out:
#   first_name  last_name                    email
# 0      Corey    Schafer  CoreyMSchafer@gmail.com
# 1       Jane        Doe        JaneDoe@email.com
# 2     daniel  ricciardo   CoreySchafer@gmail.com

# %%
df.loc[2, 'email'] = 'DanielRicciardo@gmail.com'

# %%
df
# Out:
#   first_name  last_name                      email
# 0      Corey    Schafer    CoreyMSchafer@gmail.com
# 1       Jane        Doe          JaneDoe@email.com
# 2     daniel  ricciardo  DanielRicciardo@gmail.com

# %%
filt = (df['first_name'] == 'daniel')
filt
# Out:
# 0    False
# 1    False
# 2     True
# Name: first_name, dtype: bool

# %%
df.loc[filt, ['first_name', 'last_name']] = ['Daniel', 'Ricciardo']

# %%
df
# Out:
#   first_name  last_name                      email
# 0      Corey    Schafer    CoreyMSchafer@gmail.com
# 1       Jane        Doe          JaneDoe@email.com
# 2     Daniel  Ricciardo  DanielRicciardo@gmail.com

# %% [markdown]
# ### updating multiple values in a single column, or entire dataframe
#
# apply <br>
# map <br>
# applymap <br>
# replace <br>

# %%
df['email'] = df.loc[:, 'email'].str.lower()

# %%
df
# Out:
#   first_name  last_name                      email
# 0      Corey    Schafer    coreymschafer@gmail.com
# 1       Jane        Doe          janedoe@email.com
# 2     Daniel  Ricciardo  danielricciardo@gmail.com

# %% [markdown]
# # Apply
#
# can use with both series and data frame / data frame il ulla oro columsine aanu series aayitt parayanath

# %%
df['email'].apply(len)
# Out:
# 0    23
# 1    17
# 2    25
# Name: email, dtype: int64

# %%
def update_email(email):
    return email.upper()

# %%
df['email'] = df['email'].apply(update_email)
df
# Out:
#   first_name  last_name                      email
# 0      Corey    Schafer    COREYMSCHAFER@GMAIL.COM
# 1       Jane        Doe          JANEDOE@EMAIL.COM
# 2     Daniel  Ricciardo  DANIELRICCIARDO@GMAIL.COM

# %%
df['email'] = df['email'].apply(lambda x: x.lower())
df
# Out:
#   first_name  last_name                      email
# 0      Corey    Schafer    coreymschafer@gmail.com
# 1       Jane        Doe          janedoe@email.com
# 2     Daniel  Ricciardo  danielricciardo@gmail.com

# %% [markdown]
# df.apply ennu koduthaal oro column um series aayi eduthitt ath iterate cheyyum, ennitt oro iteration il um nammude condition apply cheyyum

# %%
df.apply(len)
# Out:
# first_name    3
# last_name     3
# email         3
# dtype: int64

# %%
df.apply(lambda x: x.min())
# Out:
# first_name                      Corey
# last_name                         Doe
# email         coreymschafer@gmail.com
# dtype: object

# %% [markdown]
# ## applymap

# %%
df.applymap(len)
# Out:
#    first_name  last_name  email
# 0           5          7     23
# 1           4          3     17
# 2           6          9     25

# %%
df.applymap(str.lower)
# Out:
#   first_name  last_name                      email
# 0      corey    schafer    coreymschafer@gmail.com
# 1       jane        doe          janedoe@email.com
# 2     daniel  ricciardo  danielricciardo@gmail.com

# %%
df.applymap(str.upper)
# Out:
#   first_name  last_name                      email
# 0      COREY    SCHAFER    COREYMSCHAFER@GMAIL.COM
# 1       JANE        DOE          JANEDOE@EMAIL.COM
# 2     DANIEL  RICCIARDO  DANIELRICCIARDO@GMAIL.COM

# %%
df = df.applymap(str.lower)
df
# Out:
#   first_name  last_name                      email
# 0      corey    schafer    coreymschafer@gmail.com
# 1       jane        doe          janedoe@email.com
# 2     daniel  ricciardo  danielricciardo@gmail.com

# %%
df = pd.read_csv('survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('survey_results_schema.csv', index_col='Column')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head(5)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
# Map use cheyyumpol, thaazhathe case il true or false allaatha case il vere enthelum vannaal, ath NAN aayi set cheyyum
# ath pariharikkaan replace aanu nallatyh
df['Hobbyist'].map({'Yes':True, 'No':False})
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
#          ...
# 88377     True
# 88601    False
# 88802    False
# 88816    False
# 88863     True
# Name: Hobbyist, Length: 88883, dtype: bool

# %%
df['hobbyist'] = df['Hobbyist'].replace({'Yes':True, 'No':False})

# %%
df['hobbyist'].value_counts()
# Out:
# True     71257
# False    17626
# Name: hobbyist, dtype: int64
